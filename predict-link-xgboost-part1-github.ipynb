# %% [markdown]
# # Tutorial #1: Model training with Azure Machine Learning
#
# In this tutorial, you will train a machine learning model on local and Azure compute resources. You will explore the Azure Machine Learning service and the Azure ML SDK for Python.
# This notebook serves as a quick start to hands-on Azure Machine Learning service.
#
# Before you start this tutorial, you need to create a workspace in the Azure portal first.
# [Create and manage Azure Machine Learning workspaces in the Azure portal](https://docs.microsoft.com/en-us/azure/machine-learning/how-to-manage-workspace)
#
# The following are covered in this tutorial:
# * Extract data from Azure Search Service
# * Train a xgboost model on local machine and on Azure compute resources
# * Register the model in Azure Machine Learning Workspace
#
# If you are trying out this tutorial for the first time, please run the code cells in this tutorial sequentially.
# Tutorial #2 will cover the basics of deploying a model.
#
# ## References
#
# [Azure Machine Learning documentation](https://github.com/leekokhow/azureml/blob/master/predict-employee-retention-part1-training.ipynb).

# %% [markdown]
# ## Set up your development environment
#
# ### Dependencies required for local machine setup in order to use Azure ML SDK.
#
# Step 1. You need to create a [free Azure account](https://azure.microsoft.com/en-gb/free/) first. This tutorial will use Anaconda on your local machine to connect to your Azure account.
#
# Step 2. This notebook was tested in Anaconda Jupyter Notebook.
# Once you have installed Anaconda on your machine, run the following pip commands to download these packages into Anaconda:
#
# + conda install anaconda-client
# + conda update anaconda
# + pip install azureml-sdk[notebooks,automl]
# + pip install azureml-dataprep[pandas]
# + conda update conda
#
# **Note: If you need to upgrade the azureml components, uninstall the old version first before install the new ones.**
#
# OR you can use a [free Microsoft Azure Notebooks](https://notebooks.azure.com/) to run this notebook if you don't have Anaconda.

# %% [markdown]
# ### Import Azure Machine Learning SDK for Python
#
# This step is to check that you have installed Azure Machine Learning SDK for Python.
#
# **Note: if you encounter ModuleNotFoundError, try uninstall all the azureml components first then re-install them again.**

# %%
import azureml.core

# check core SDK version number (need Python 3.6 kernel if you run this in Microsoft Azure Notebooks)
print("Azure ML SDK Version: ", azureml.core.VERSION)
# Out:
# Azure ML SDK Version:  1.24.0

# %% [markdown]
# ### Connect Azure Machine Learning Workspace
#
# Create a workspace object from the existing workspace. `Workspace.from_config()` reads the file **config.json** and loads the details into an object named `workspace`.
#
# If you see this message:
# "Performing interactive authentication. Please follow the instructions on the terminal.
# To sign in, use a web browser to open the page https://microsoft.com/devicelogin and enter the code &lt;token\&gt; to authenticate."
#
# Click on the link and use the &lt;token\&gt; given to authenticate. After authenticated, run this script again to get load the Workspace.&lt;/token\&gt;&lt;/token\&gt;

# %%
# Load workspace configuration from the config.json file in the current folder.
from azureml.core import Workspace
workspace = Workspace.from_config()
# print(workspace.name, workspace.location, workspace.resource_group, sep='\t')

# %% [markdown]
# ### Create an Experiment
#
# An Experiment tracks the runs in your workspace. A workspace can have muliple experiments.

# %%
from azureml.core import Experiment

experiment_name = 'predict-link-xgboost'
exp = Experiment(workspace=workspace, name=experiment_name)

# %% [markdown]
# ## Extract data
#
# This example read api data from Azure Search Service. It requires a api_config.json that has Azure Search Service credentials. A python script **azure_search_client.py** which has helper functions which help to extract data from Azure Search Service.

# %%
from azure_search_client import azure_search_client as azs_client 
from pandas.io.json import json_normalize
import pandas as pd
import json
import concurrent
import datetime
from itertools import chain
import random
import numpy as np
from random import sample
import warnings
warnings.filterwarnings("ignore")
from sklearn.model_selection import GroupShuffleSplit
import xgboost as xgb
from sklearn.model_selection import GroupKFold
from tqdm import tqdm

# %% [markdown]
# ### *get_search_results*
#
# This function sends the query into azure search service and produce the results in json format.
#
# read in 2 inputs : service and query.
# 1. service :class, is a class created using azure_search_client.py
# 2. query :string, what we wish to send to the azure search service.
#
# output: json dictionary
#
# ### *retrieve_from_search*
#
# This function calls *get_search_results* and flatten the json output into pandas dataframe. It then creates session id and query column.
#
# read in 3 inputs : query, sessionid, azs_service
# 1. service :class, is a class created using azure_search_client.py
# 2. query :string, what we wish to send to the azure search service.
# 3. sessionid :int
#
# output: pandas dataframe

# %%
def get_search_results(service, query):
    search_request_body = {
        "search": query,
        "featuresMode": "enabled",
        "scoringStatistics": "global",
        "count": "true"
    }
    return service.search(search_request_body)

def retrieve_from_search(query, sessionid, azs_service):
    
    ## Call the api service to retrieve json format data
    json_search_results = get_search_results(azs_service, query)
    
    ## Flatten the json format data into pandas dataframe
    search_results = json_normalize(json_search_results).fillna(0)
    search_results['query'] = query.lower()
    search_results['sessionid'] = sessionid
    print('{} rows for query : {}'.format(search_results.shape[0], query))
    
    return search_results

# %% [markdown]
# This code connects to the api service using the api_config json that we created. You may follow the Step 13 of **Guide for Azure Search Service.pdf** to understand the location in retrieving the credentials required.
#
# The api_config.json looks like this:
#
#
# {"service_name": "xxxxx",
#     "endpoint": "xxxxx",
#     "api_version": "2020-06-30-preview",
#     "api_key": "xxxxx",
#     "index_name": "xxxxx"}

# %%
azs_service = azs_client.from_json('api_config.json')
azs_service

# %% [markdown]
# The following code creates hardcoded queries that would be send to the search service using the function <i>retrieve_from_search</i>.

# %%
# Create the necessary queries to create dataset
query_input = ['powershell', 'power bi', 'power', 'azure', 'azure powershell', 'power']

demo_query_dataset = pd.DataFrame()
sessionid =1
for query in query_input:
    demo_query_dataset = pd.concat([demo_query_dataset, retrieve_from_search(query, sessionid, azs_service)])
    sessionid+=1
    
demo_query_dataset['grade'] = demo_query_dataset['grade'].astype(int)
demo_query_dataset
# Out:
# 10 rows for query : powershell
# 10 rows for query : power bi
# 10 rows for query : power
# 3 rows for query : azure
# 12 rows for query : azure powershell
# 10 rows for query : power
#     @search.features.keyphrases.similarityScore  \
# 0                                      0.802591
# 1                                      0.802591
# 2                                      0.802591
# 3                                      0.802591
# 4                                      0.802591
# 5                                      0.802591
# 6                                      0.802591
# 7                                      0.802591
# 8                                      0.802591
# 9                                      0.802591
# 0                                      1.075405
# 1                                      1.075405
# 2                                      1.075405
# 3                                      1.075405
# 4                                      1.075405
# 5                                      1.075405
# 6                                      1.075405
# 7                                      1.075405
# 8                                      1.075405
# 9                                      1.075405
# 0                                      0.537702
# 1                                      0.537702
# 2                                      0.537702
# 3                                      0.537702
# 4                                      0.537702
# 5                                      0.537702
# 6                                      0.537702
# 7                                      0.537702
# 8                                      0.537702
# 9                                      0.537702
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
#
# 0                                       1.0       2.432947
# 1                                       1.0       1.759443
# 2                                       1.0       1.423373
# 0                                       2.0       4.045271
# 1                                       1.0       2.546375
# 2                                       1.0       2.546375
# 3                                       1.0       2.461978
# 4                                       1.0       2.432947
# 5                                       1.0       2.414292
# 6                                       1.0       2.414292
# 7                                       1.0       2.414292
# 8                                       1.0       2.385969
# 9                                       1.0       2.285828
# 10                                      1.0       2.155819
# 11                                      1.0       1.423373
# 0                                       1.0       2.152496
# 1                                       1.0       2.001342
# 2                                       1.0       2.001342
# 3                                       1.0       1.968929
# 4                                       1.0       1.854329
# 5                                       1.0       1.854329
# 6                                       1.0       1.854329
# 7                                       1.0       1.854329
# 8                                       1.0       1.705547
# 9                                       0.0       1.075405
#
#                               AzureSearch_DocumentKey  grade    keyphrases  \
# 0   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      7  [powershell]
# 1   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      6  [powershell]
# 2   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      9  [powershell]
# 3   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      5  [powershell]
# 4   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      4  [powershell]
# 5   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      2  [powershell]
# 6   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...     10  [powershell]
# 7   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      8  [powershell]
# 8   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      3  [powershell]
# 9   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      1  [powershell]
# 0   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...     10    [power bi]
# 1   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      5    [power bi]
# 2   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      1    [power bi]
# 3   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      8    [power bi]
# 4   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      9    [power bi]
# 5   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      7    [power bi]
# 6   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      4    [power bi]
# 7   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      3    [power bi]
# 8   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      6    [power bi]
# 9   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      2    [power bi]
# 0   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...     10    [power bi]
# 1   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      5    [power bi]
# 2   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      1    [power bi]
# 3   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      8    [power bi]
# 4   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      9    [power bi]
# 5   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      7    [power bi]
# 6   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      4    [power bi]
# 7   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      3    [power bi]
# 8   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      6    [power bi]
# 9   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      2    [power bi]
# 0   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      2    [power bi]
# 1   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      3  [powershell]
# 2   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      1    [power bi]
# 0   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      3  [powershell]
# 1   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      7  [powershell]
# 2   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      6  [powershell]
# 3   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      9  [powershell]
# 4   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      2    [power bi]
# 5   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      5  [powershell]
# 6   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      4  [powershell]
# 7   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      2  [powershell]
# 8   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...     10  [powershell]
# 9   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      8  [powershell]
# 10  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      1  [powershell]
# 11  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      1    [power bi]
# 0   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...     10    [power bi]
# 1   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      5    [power bi]
# 2   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      1    [power bi]
# 3   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      8    [power bi]
# 4   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      9    [power bi]
# 5   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      7    [power bi]
# 6   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      4    [power bi]
# 7   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      3    [power bi]
# 8   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      6    [power bi]
# 9   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      2    [power bi]
#
#                query  sessionid  \
# 0         powershell          1
# 1         powershell          1
# 2         powershell          1
# 3         powershell          1
# 4         powershell          1
# 5         powershell          1
# 6         powershell          1
# 7         powershell          1
# 8         powershell          1
# 9         powershell          1
# 0           power bi          2
# 1           power bi          2
# 2           power bi          2
# 3           power bi          2
# 4           power bi          2
# 5           power bi          2
# 6           power bi          2
# 7           power bi          2
# 8           power bi          2
# 9           power bi          2
# 0              power          3
# 1              power          3
# 2              power          3
# 3              power          3
# 4              power          3
# 5              power          3
# 6              power          3
# 7              power          3
# 8              power          3
# 9              power          3
# 0              azure          4
# 1              azure          4
# 2              azure          4
# 0   azure powershell          5
# 1   azure powershell          5
# 2   azure powershell          5
# 3   azure powershell          5
# 4   azure powershell          5
# 5   azure powershell          5
# 6   azure powershell          5
# 7   azure powershell          5
# 8   azure powershell          5
# 9   azure powershell          5
# 10  azure powershell          5
# 11  azure powershell          5
# 0              power          6
# 1              power          6
# 2              power          6
# 3              power          6
# 4              power          6
# 5              power          6
# 6              power          6
# 7              power          6
# 8              power          6
# 9              power          6
#
#                                                   url
# 0   https://docs.microsoft.com/en-us/powershell/sc...
# 1   https://docs.microsoft.com/en-us/powershell/sc...
# 2        https://docs.microsoft.com/en-us/powershell/
# 3   https://docs.microsoft.com/en-us/powershell/sc...
# 4   https://docs.microsoft.com/en-us/powershell/sc...
# 5   https://docs.microsoft.com/en-us/powershell/sc...
# 6   https://docs.microsoft.com/en-us/powershell/sc...
# 7   https://docs.microsoft.com/en-us/windows-serve...
# 8   https://docs.microsoft.com/en-us/powershell/az...
# 9   https://docs.microsoft.com/en-us/virtualizatio...
# 0   https://docs.microsoft.com/en-us/power-bi/fund...
# 1   https://docs.microsoft.com/en-us/power-bi/serv...
# 2   https://docs.microsoft.com/en-us/power-bi/serv...
# 3          https://docs.microsoft.com/en-us/power-bi/
# 4   https://docs.microsoft.com/en-us/power-bi/guid...
# 5   https://docs.microsoft.com/en-us/power-bi/serv...
# 6   https://docs.microsoft.com/en-us/power-bi/desk...
# 7   https://docs.microsoft.com/en-us/power-bi/desk...
# 8   https://docs.microsoft.com/en-us/learn/modules...
# 9   https://docs.microsoft.com/en-us/azure/azure-m...
# 0   https://docs.microsoft.com/en-us/power-bi/fund...
# 1   https://docs.microsoft.com/en-us/power-bi/serv...
# 2   https://docs.microsoft.com/en-us/power-bi/serv...
# 3          https://docs.microsoft.com/en-us/power-bi/
# 4   https://docs.microsoft.com/en-us/power-bi/guid...
# 5   https://docs.microsoft.com/en-us/power-bi/serv...
# 6   https://docs.microsoft.com/en-us/power-bi/desk...
# 7   https://docs.microsoft.com/en-us/power-bi/desk...
# 8   https://docs.microsoft.com/en-us/learn/modules...
# 9   https://docs.microsoft.com/en-us/azure/azure-m...
# 0   https://docs.microsoft.com/en-us/azure/azure-m...
# 1   https://docs.microsoft.com/en-us/powershell/az...
# 2   https://docs.microsoft.com/en-us/power-bi/serv...
# 0   https://docs.microsoft.com/en-us/powershell/az...
# 1   https://docs.microsoft.com/en-us/powershell/sc...
# 2   https://docs.microsoft.com/en-us/powershell/sc...
# 3        https://docs.microsoft.com/en-us/powershell/
# 4   https://docs.microsoft.com/en-us/azure/azure-m...
# 5   https://docs.microsoft.com/en-us/powershell/sc...
# 6   https://docs.microsoft.com/en-us/powershell/sc...
# 7   https://docs.microsoft.com/en-us/powershell/sc...
# 8   https://docs.microsoft.com/en-us/powershell/sc...
# 9   https://docs.microsoft.com/en-us/windows-serve...
# 10  https://docs.microsoft.com/en-us/virtualizatio...
# 11  https://docs.microsoft.com/en-us/power-bi/serv...
# 0   https://docs.microsoft.com/en-us/power-bi/fund...
# 1   https://docs.microsoft.com/en-us/power-bi/serv...
# 2   https://docs.microsoft.com/en-us/power-bi/serv...
# 3          https://docs.microsoft.com/en-us/power-bi/
# 4   https://docs.microsoft.com/en-us/power-bi/guid...
# 5   https://docs.microsoft.com/en-us/power-bi/serv...
# 6   https://docs.microsoft.com/en-us/power-bi/desk...
# 7   https://docs.microsoft.com/en-us/power-bi/desk...
# 8   https://docs.microsoft.com/en-us/learn/modules...
# 9   https://docs.microsoft.com/en-us/azure/azure-m...

# %% [markdown]
# ### Saving the dataset into blob storage
# We can use code to save our dataframe demo_query_dataset into a file and push this file into our datastore. As such, other members just require the file directory in the datastore to read this file.

# %%
from azureml.core import Workspace, Dataset
os.makedirs('data', exist_ok=True)
local_path = 'data/demo_query_dataset.csv'
demo_query_dataset.to_csv(local_path)

# get the datastore to upload prepared data
datastore = workspace.get_default_datastore()

# upload the local file from src_dir to the target_path in datastore
datastore.upload(src_dir='data', target_path='data', overwrite=True)

# reading the dataset referencing from datastore, 
# use .from_delimited_files as we are reading from csv
reading_dataset = Dataset.Tabular.from_delimited_files(path = [(datastore, ('data/demo_query_dataset.csv'))])

demo_query_dataset = reading_dataset.to_pandas_dataframe()
demo_query_dataset.head()
# Out:
# Uploading an estimated of 1 files
# Uploading data/demo_query_dataset.csv
# Uploaded data/demo_query_dataset.csv, 1 files out of an estimated total of 1
# Uploaded 1 files
#    Column1  @search.features.keyphrases.similarityScore  \
# 0        0                                     0.802591
# 1        1                                     0.802591
# 2        2                                     0.802591
# 3        3                                     0.802591
# 4        4                                     0.802591
#
#    @search.features.keyphrases.termFrequency  \
# 0                                        1.0
# 1                                        1.0
# 2                                        1.0
# 3                                        1.0
# 4                                        1.0
#
#    @search.features.keyphrases.uniqueTokenMatches  \
# 0                                             1.0
# 1                                             1.0
# 2                                             1.0
# 3                                             1.0
# 4                                             1.0
#
#    @search.features.query.similarityScore  \
# 0                                0.802591
# 1                                0.802591
# 2                                0.802591
# 3                                0.802591
# 4                                0.802591
#
#    @search.features.query.termFrequency  \
# 0                                   1.0
# 1                                   1.0
# 2                                   1.0
# 3                                   1.0
# 4                                   1.0
#
#    @search.features.query.uniqueTokenMatches  \
# 0                                        1.0
# 1                                        1.0
# 2                                        1.0
# 3                                        1.0
# 4                                        1.0
#
#    @search.features.url.similarityScore  @search.features.url.termFrequency  \
# 0                              0.941192                                 2.0
# 1                              0.941192                                 2.0
# 2                              0.856795                                 1.0
# 3                              0.809110                                 2.0
# 4                              0.809110                                 2.0
#
#    @search.features.url.uniqueTokenMatches  @search.score  \
# 0                                      1.0       2.546375
# 1                                      1.0       2.546375
# 2                                      1.0       2.461978
# 3                                      1.0       2.414292
# 4                                      1.0       2.414292
#
#                              AzureSearch_DocumentKey  grade      keyphrases  \
# 0  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      7  ['powershell']
# 1  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      6  ['powershell']
# 2  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      9  ['powershell']
# 3  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      5  ['powershell']
# 4  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      4  ['powershell']
#
#         query  sessionid                                                url
# 0  powershell          1  https://docs.microsoft.com/en-us/powershell/sc...
# 1  powershell          1  https://docs.microsoft.com/en-us/powershell/sc...
# 2  powershell          1       https://docs.microsoft.com/en-us/powershell/
# 3  powershell          1  https://docs.microsoft.com/en-us/powershell/sc...
# 4  powershell          1  https://docs.microsoft.com/en-us/powershell/sc...

# %% [markdown]
# ### To register the file as a dataset in AzureML workspace, we have ensure that our dataframe is a Dataset object
# The code __Dataset.Tabular.from_delimited_files__ creates a Dataset Object. We require our pandas dataframe to be a Dataset Object in order to register it in our AzureML Workspace. To convert Dataset Object to pandas dataframe, we just need to run __reading_dataset.to_pandas_dataframe()__
#
# + create_new_version = True to allow updates to the current registered dataset

# %%
from azureml.core import Dataset

## This code has been run above to read as a dataset object from file name in datastore
# reading_dataset = Dataset.Tabular.from_delimited_files(path = [(datastore, ('data/query_dataset.csv'))])
reading_dataset.register(workspace=workspace, name='demo_query_dataset_tabular',create_new_version=True)
# Out:
# {
#   "source": [
#     "('workspaceblobstore', 'data/demo_query_dataset.csv')"
#   ],
#   "definition": [
#     "GetDatastoreFiles",
#     "ParseDelimited",
#     "DropColumns",
#     "SetColumnTypes"
#   ],
#   "registration": {
#     "id": "339d58c9-e793-4966-b88f-ab501ec79701",
#     "name": "demo_query_dataset_tabular",
#     "version": 1,
#     "workspace": "Workspace.create(name='csidmlws', subscription_id='ebe8d9fa-67d0-4af1-bce2-4a5b07e50a42', resource_group='cmt-202011001')"
#   }
# }

# %% [markdown]
# ### To ensure that the dataset registered in the workspace is the same as our demo_query_dataset, we can read the dataset from our created Dataset object in our workspace

# %%
from azureml.core import Workspace, Dataset

dataset = Dataset.get_by_name(workspace, name='demo_query_dataset_tabular')
query_dataset = dataset.to_pandas_dataframe()

query_dataset
# Out:
#     Column1  @search.features.keyphrases.similarityScore  \
# 0         0                                     0.802591
# 1         1                                     0.802591
# 2         2                                     0.802591
# 3         3                                     0.802591
# 4         4                                     0.802591
# 5         5                                     0.802591
# 6         6                                     0.802591
# 7         7                                     0.802591
# 8         8                                     0.802591
# 9         9                                     0.802591
# 10        0                                     1.075405
# 11        1                                     1.075405
# 12        2                                     1.075405
# 13        3                                     1.075405
# 14        4                                     1.075405
# 15        5                                     1.075405
# 16        6                                     1.075405
# 17        7                                     1.075405
# 18        8                                     1.075405
# 19        9                                     1.075405
# 20        0                                     0.537702
# 21        1                                     0.537702
# 22        2                                     0.537702
# 23        3                                     0.537702
# 24        4                                     0.537702
# 25        5                                     0.537702
# 26        6                                     0.537702
# 27        7                                     0.537702
# 28        8                                     0.537702
# 29        9                                     0.537702
# 30        0                                          NaN
# 31        1                                          NaN
# 32        2                                          NaN
# 33        0                                     0.802591
# 34        1                                     0.802591
# 35        2                                     0.802591
# 36        3                                     0.802591
# 37        4                                     0.000000
# 38        5                                     0.802591
# 39        6                                     0.802591
# 40        7                                     0.802591
# 41        8                                     0.802591
# 42        9                                     0.802591
# 43       10                                     0.802591
# 44       11                                     0.000000
# 45        0                                     0.537702
# 46        1                                     0.537702
# 47        2                                     0.537702
# 48        3                                     0.537702
# 49        4                                     0.537702
# 50        5                                     0.537702
# 51        6                                     0.537702
# 52        7                                     0.537702
# 53        8                                     0.537702
# 54        9                                     0.537702
#
#     @search.features.keyphrases.termFrequency  \
# 0                                         1.0
# 1                                         1.0
# 2                                         1.0
# 3                                         1.0
# 4                                         1.0
# 5                                         1.0
# 6                                         1.0
# 7                                         1.0
# 8                                         1.0
# 9                                         1.0
# 10                                        2.0
# 11                                        2.0
# 12                                        2.0
# 13                                        2.0
# 14                                        2.0
# 15                                        2.0
# 16                                        2.0
# 17                                        2.0
# 18                                        2.0
# 19                                        2.0
# 20                                        1.0
# 21                                        1.0
# 22                                        1.0
# 23                                        1.0
# 24                                        1.0
# 25                                        1.0
# 26                                        1.0
# 27                                        1.0
# 28                                        1.0
# 29                                        1.0
# 30                                        NaN
# 31                                        NaN
# 32                                        NaN
# 33                                
# 7                                       1.0       2.285828
# 8                                       1.0       2.285828
# 9                                       1.0       2.155819
# 10                                      2.0       4.304992
# 11                                      2.0       4.002683
# 12                                      2.0       4.002683
# 13                                      2.0       3.937858
# 14                                      2.0       3.708657
# 15                                      2.0       3.708657
# 16                                      2.0       3.708657
# 17                                      2.0       3.708657
# 18                                      2.0       3.411093
# 19                                      0.0       2.150809
# 20                                      1.0       2.152496
# 21                                      1.0       2.001342
# 22                                      1.0       2.001342
# 23                                      1.0       1.968929
# 24                                      1.0       1.854329
# 25                                      1.0       1.854329
# 26                                      1.0       1.854329
# 27                                      1.0       1.854329
# 28                                      1.0       1.705547
# 29                                      0.0       1.075405
# 30                                      1.0       2.432947
# 31                                      1.0       1.759443
# 32                                      1.0       1.423373
# 33                                      2.0       4.045271
# 34                                      1.0       2.546375
# 35                                      1.0       2.546375
# 36                                      1.0       2.461978
# 37                                      1.0       2.432947
# 38                                      1.0       2.414292
# 39                                      1.0       2.414292
# 40                                      1.0       2.414292
# 41                                      1.0       2.385969
# 42                                      1.0       2.285828
# 43                                      1.0       2.155819
# 44                                      1.0       1.423373
# 45                                      1.0       2.152496
# 46                                      1.0       2.001342
# 47                                      1.0       2.001342
# 48                                      1.0       1.968929
# 49                                      1.0       1.854329
# 50                                      1.0       1.854329
# 51                                      1.0       1.854329
# 52                                      1.0       1.854329
# 53                                      1.0       1.705547
# 54                                      0.0       1.075405
#
#                               AzureSearch_DocumentKey  grade      keyphrases  \
# 0   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      7  ['powershell']
# 1   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      6  ['powershell']
# 2   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      9  ['powershell']
# 3   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      5  ['powershell']
# 4   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      4  ['powershell']
# 5   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      2  ['powershell']
# 6   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...     10  ['powershell']
# 7   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      8  ['powershell']
# 8   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      3  ['powershell']
# 9   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      1  ['powershell']
# 10  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...     10    ['power bi']
# 11  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      5    ['power bi']
# 12  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      1    ['power bi']
# 13  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      8    ['power bi']
# 14  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      9    ['power bi']
# 15  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      7    ['power bi']
# 16  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      4    ['power bi']
# 17  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      3    ['power bi']
# 18  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      6    ['power bi']
# 19  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      2    ['power bi']
# 20  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...     10    ['power bi']
# 21  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      5    ['power bi']
# 22  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      1    ['power bi']
# 23  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      8    ['power bi']
# 24  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      9    ['power bi']
# 25  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      7    ['power bi']
# 26  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      4    ['power bi']
# 27  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      3    ['power bi']
# 28  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      6    ['power bi']
# 29  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      2    ['power bi']
# 30  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      2    ['power bi']
# 31  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      3  ['powershell']
# 32  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      1    ['power bi']
# 33  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      3  ['powershell']
# 34  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      7  ['powershell']
# 35  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      6  ['powershell']
# 36  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      9  ['powershell']
# 37  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      2    ['power bi']
# 38  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      5  ['powershell']
# 39  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      4  ['powershell']
# 40  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      2  ['powershell']
# 41  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...     10  ['powershell']
# 42  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      8  ['powershell']
# 43  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      1  ['powershell']
# 44  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      1    ['power bi']
# 45  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...     10    ['power bi']
# 46  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      5    ['power bi']
# 47  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      1    ['power bi']
# 48  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      8    ['power bi']
# 49  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      9    ['power bi']
# 50  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      7    ['power bi']
# 51  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      4    ['power bi']
# 52  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      3    ['power bi']
# 53  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      6    ['power bi']
# 54  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      2    ['power bi']
#
#                query  sessionid  \
# 0         powershell          1
# 1         powershell          1
# 2         powershell          1
# 3         powershell          1
# 4         powershell          1
# 5         powershell          1
# 6         powershell          1
# 7         powershell          1
# 8         powershell          1
# 9         powershell          1
# 10          power bi          2
# 11          power bi          2
# 12          power bi          2
# 13          power bi          2
# 14          power bi          2
# 15          power bi          2
# 16          power bi          2
# 17          power bi          2
# 18          power bi          2
# 19          power bi          2
# 20             power          3
# 21             power          3
# 22             power          3
# 23             power          3
# 24             power          3
# 25             power          3
# 26             power          3
# 27             power          3
# 28             power          3
# 29             power          3
# 30             azure          4
# 31             azure          4
# 32             azure          4
# 33  azure powershell          5
# 34  azure powershell          5
# 35  azure powershell          5
# 36  azure powershell          5
# 37  azure powershell          5
# 38  azure powershell          5
# 39  azure powershell          5
# 40  azure powershell          5
# 41  azure powershell          5
# 42  azure powershell          5
# 43  azure powershell          5
# 44  azure powershell          5
# 45             power          6
# 46             power          6
# 47             power          6
# 48             power          6
# 49             power          6
# 50             power          6
# 51             power          6
# 52             power          6
# 53             power          6
# 54             power          6
#
#                                                   url
# 0   https://docs.microsoft.com/en-us/powershell/sc...
# 1   https://docs.microsoft.com/en-us/powershell/sc...
# 2        https://docs.microsoft.com/en-us/powershell/
# 3   https://docs.microsoft.com/en-us/powershell/sc...
# 4   https://docs.microsoft.com/en-us/powershell/sc...
# 5   https://docs.microsoft.com/en-us/powershell/sc...
# 6   https://docs.microsoft.com/en-us/powershell/sc...
# 7   https://docs.microsoft.com/en-us/windows-serve...
# 8   https://docs.microsoft.com/en-us/powershell/az...
# 9   https://docs.microsoft.com/en-us/virtualizatio...
# 10  https://docs.microsoft.com/en-us/power-bi/fund...
# 11  https://docs.microsoft.com/en-us/power-bi/serv...
# 12  https://docs.microsoft.com/en-us/power-bi/serv...
# 13         https://docs.microsoft.com/en-us/power-bi/
# 14  https://docs.microsoft.com/en-us/power-bi/guid...
# 15  https://docs.microsoft.com/en-us/power-bi/serv...
# 16  https://docs.microsoft.com/en-us/power-bi/desk...
# 17  https://docs.microsoft.com/en-us/power-bi/desk...
# 18  https://docs.microsoft.com/en-us/learn/modules...
# 19  https://docs.microsoft.com/en-us/azure/azure-m...
# 20  https://docs.microsoft.com/en-us/power-bi/fund...
# 21  https://docs.microsoft.com/en-us/power-bi/serv...
# 22  https://docs.microsoft.com/en-us/power-bi/serv...
# 23         https://docs.microsoft.com/en-us/power-bi/
# 24  https://docs.microsoft.com/en-us/power-bi/guid...
# 25  https://docs.microsoft.com/en-us/power-bi/serv...
# 26  https://docs.microsoft.com/en-us/power-bi/desk...
# 27  https://docs.microsoft.com/en-us/power-bi/desk...
# 28  https://docs.microsoft.com/en-us/learn/modules...
# 29  https://docs.microsoft.com/en-us/azure/azure-m...
# 30  https://docs.microsoft.com/en-us/azure/azure-m...
# 31  https://docs.microsoft.com/en-us/powershell/az...
# 32  https://docs.microsoft.com/en-us/power-bi/serv...
# 33  https://docs.microsoft.com/en-us/powershell/az...
# 34  https://docs.microsoft.com/en-us/powershell/sc...
# 35  https://docs.microsoft.com/en-us/powershell/sc...
# 36       https://docs.microsoft.com/en-us/powershell/
# 37  https://docs.microsoft.com/en-us/azure/azure-m...
# 38  https://docs.microsoft.com/en-us/powershell/sc...
# 39  https://docs.microsoft.com/en-us/powershell/sc...
# 40  https://docs.microsoft.com/en-us/powershell/sc...
# 41  https://docs.microsoft.com/en-us/powershell/sc...
# 14                                      2.0       3.708657
# 15                                      2.0       3.708657
# 16                                      2.0       3.708657
# 17                                      2.0       3.708657
# 18                                      2.0       3.411093
# 19                                      0.0       2.150809
# 20                                      1.0       2.152496
# 21                                      1.0       2.001342
# 22                                      1.0       2.001342
# 23                                      1.0       1.968929
# 24                                      1.0       1.854329
# 25                                      1.0       1.854329
# 26                                      1.0       1.854329
# 27                                      1.0       1.854329
# 28                                      1.0       1.705547
# 29                                      0.0       1.075405
# 30                                      1.0       2.432947
# 31                                      1.0       1.759443
# 32                                      1.0       1.423373
# 33                                      2.0       4.045271
# 34                                      1.0       2.546375
# 35                                      1.0       2.546375
# 36                                      1.0       2.461978
# 37                                      1.0       2.432947
# 38                                      1.0       2.414292
# 39                                      1.0       2.414292
# 40                                      1.0       2.414292
# 41                                      1.0       2.385969
# 42                                      1.0       2.285828
# 43                                      1.0       2.155819
# 44                                      1.0       1.423373
# 45                                      1.0       2.152496
# 46                                      1.0       2.001342
# 47                                      1.0       2.001342
# 48                                      1.0       1.968929
# 49                                      1.0       1.854329
# 50                                      1.0       1.854329
# 51                                      1.0       1.854329
# 52                                      1.0       1.854329
# 53                                      1.0       1.705547
# 54                                      0.0       1.075405
#
#                               AzureSearch_DocumentKey  grade      keyphrases  \
# 0   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      7  ['powershell']
# 1   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      6  ['powershell']
# 2   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      9  ['powershell']
# 3   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      5  ['powershell']
# 4   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      4  ['powershell']
# 5   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      2  ['powershell']
# 6   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...     10  ['powershell']
# 7   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      8  ['powershell']
# 8   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      3  ['powershell']
# 9   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      1  ['powershell']
# 10  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...     10    ['power bi']
# 11  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      5    ['power bi']
# 12  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      1    ['power bi']
# 13  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      8    ['power bi']
# 14  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      9    ['power bi']
# 15  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      7    ['power bi']
# 16  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      4    ['power bi']
# 17  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      3    ['power bi']
# 18  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      6    ['power bi']
# 19  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      2    ['power bi']
# 20  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...     10    ['power bi']
# 21  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      5    ['power bi']
# 22  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      1    ['power bi']
# 23  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      8    ['power bi']
# 24  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      9    ['power bi']
# 25  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      7    ['power bi']
# 26  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      4    ['power bi']
# 27  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      3    ['power bi']
# 28  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      6    ['power bi']
# 29  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      2    ['power bi']
# 30  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      2    ['power bi']
# 31  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      3  ['powershell']
# 32  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      1    ['power bi']
# 33  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      3  ['powershell']
# 34  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      7  ['powershell']
# 35  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      6  ['powershell']
# 36  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      9  ['powershell']
# 37  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      2    ['power bi']
# 38  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      5  ['powershell']
# 39  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      4  ['powershell']
# 40  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      2  ['powershell']
# 41  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...     10  ['powershell']
# 42  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      8  ['powershell']
# 43  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      1  ['powershell']
# 44  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      1    ['power bi']
# 45  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...     10    ['power bi']
# 46  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      5    ['power bi']
# 47  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      1    ['power bi']
# 48  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      8    ['power bi']
# 49  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      9    ['power bi']
# 50  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      7    ['power bi']
# 51  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      4    ['power bi']
# 52  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      3    ['power bi']
# 53  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      6    ['power bi']
# 54  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      2    ['power bi']
#
#                query  sessionid  \
# 0         powershell          1
# 1         powershell          1
# 2         powershell          1
# 3         powershell          1
# 4         powershell          1
# 5         powershell          1
# 6         powershell          1
# 7         powershell          1
# 8         powershell          1
# 9         powershell          1
# 10          power bi          2
# 11          power bi          2
# 12          power bi          2
# 13          power bi          2
# 14          power bi          2
# 15          power bi          2
# 16          power bi          2
# 17          power bi          2
# 18          power bi          2
# 19          power bi          2
# 20             power          3
# 21             power          3
# 22             power          3
# 23             power          3
# 24             power          3
# 25             power          3
# 26             power          3
# 27             power          3
# 28             power          3
# 29             power          3
# 30             azure          4
# 31             azure          4
# 32             azure          4
# 33  azure powershell          5
# 34  azure powershell          5
# 35  azure powershell          5
# 36  azure powershell          5
# 37  azure powershell          5
# 38  azure powershell          5
# 39  azure powershell          5
# 40  azure powershell          5
# 41  azure powershell          5
# 42  azure powershell          5
# 43  azure powershell          5
# 44  azure powershell          5
# 45             power          6
# 46             power          6
# 47             power          6
# 48             power          6
# 49             power          6
# 50             power          6
# 51             power          6
# 52             power          6
# 53             power          6
# 54             power          6
#
#                                                   url
# 0   https://docs.microsoft.com/en-us/powershell/sc...
# 1   https://docs.microsoft.com/en-us/powershell/sc...
# 2        https://docs.microsoft.com/en-us/powershell/
# 3   https://docs.microsoft.com/en-us/powershell/sc...
# 4   https://docs.microsoft.com/en-us/powershell/sc...
# 5   https://docs.microsoft.com/en-us/powershell/sc...
# 6   https://docs.microsoft.com/en-us/powershell/sc...
# 7   https://docs.microsoft.com/en-us/windows-serve...
# 8   https://docs.microsoft.com/en-us/powershell/az...
# 9   https://docs.microsoft.com/en-us/virtualizatio...
# 10  https://docs.microsoft.com/en-us/power-bi/fund...
# 11  https://docs.microsoft.com/en-us/power-bi/serv...
# 12  https://docs.microsoft.com/en-us/power-bi/serv...
# 13         https://docs.microsoft.com/en-us/power-bi/
# 14  https://docs.microsoft.com/en-us/power-bi/guid...
# 15  https://docs.microsoft.com/en-us/power-bi/serv...
# 16  https://docs.microsoft.com/en-us/power-bi/desk...
# 17  https://docs.microsoft.com/en-us/power-bi/desk...
# 18  https://docs.microsoft.com/en-us/learn/modules...
# 19  https://docs.microsoft.com/en-us/azure/azure-m...
# 20  https://docs.microsoft.com/en-us/power-bi/fund...
# 21  https://docs.microsoft.com/en-us/power-bi/serv...
# 22  https://docs.microsoft.com/en-us/power-bi/serv...
# 23         https://docs.microsoft.com/en-us/power-bi/
# 24  https://docs.microsoft.com/en-us/power-bi/guid...
# 25  https://docs.microsoft.com/en-us/power-bi/serv...
# 26  https://docs.microsoft.com/en-us/power-bi/desk...
# 27  https://docs.microsoft.com/en-us/power-bi/desk...
# 28  https://docs.microsoft.com/en-us/learn/modules...
# 29  https://docs.microsoft.com/en-us/azure/azure-m...
# 30  https://docs.microsoft.com/en-us/azure/azure-m...
# 31  https://docs.microsoft.com/en-us/powershell/az...
# 32  https://docs.microsoft.com/en-us/power-bi/serv...
# 33  https://docs.microsoft.com/en-us/powershell/az...
# 34  https://docs.microsoft.com/en-us/powershell/sc...
# 35  https://docs.microsoft.com/en-us/powershell/sc...
# 36       https://docs.microsoft.com/en-us/powershell/
# 37  https://docs.microsoft.com/en-us/azure/azure-m...
# 38  https://docs.microsoft.com/en-us/powershell/sc...
# 39  https://docs.microsoft.com/en-us/powershell/sc...
# 40  https://docs.microsoft.com/en-us/powershell/sc...
# 41  https://docs.microsoft.com/en-us/powershell/sc...
# 42  https://docs.microsoft.com/en-us/windows-serve...
# 43  https://docs.microsoft.com/en-us/virtualizatio...
# 44  https://docs.microsoft.com/en-us/power-bi/serv...
# 45  https://docs.microsoft.com/en-us/power-bi/fund...
# 46  https://docs.microsoft.com/en-us/power-bi/serv...
# 47  https://docs.microsoft.com/en-us/power-bi/serv...
# 48         https://docs.microsoft.com/en-us/power-bi/
# 49  https://docs.microsoft.com/en-us/power-bi/guid...
# 50  https://docs.microsoft.com/en-us/power-bi/serv...
# 51  https://docs.microsoft.com/en-us/power-bi/desk...
# 52  https://docs.microsoft.com/en-us/power-bi/desk...
# 53  https://docs.microsoft.com/en-us/learn/modules...
# 54  https://docs.microsoft.com/en-us/azure/azure-m...

# %% [markdown]
# The next step would be to create a simple XGBRanker model from xgboost package to run prediction on our query_dataset. The scores are how the outputs of each group are in comparision with each other. The higher the score would be better. For simplicity, I will not do any train test split. I will run my model again on the train dataset.

# %%
features = ['@search.features.keyphrases.similarityScore',
       '@search.features.keyphrases.termFrequency',
       '@search.features.keyphrases.uniqueTokenMatches',
       '@search.features.query.similarityScore',
       '@search.features.query.termFrequency',
       '@search.features.query.uniqueTokenMatches',
       '@search.features.url.similarityScore',
       '@search.features.url.termFrequency',
       '@search.features.url.uniqueTokenMatches', '@search.score']

X, y = demo_query_dataset[features], demo_query_dataset.grade

#### Query labels for each document in our dataset.
query_ids = demo_query_dataset['sessionid'].to_numpy()

params = {'objective': 'rank:ndcg', 'learning_rate': 0.5
          ,'min_child_weight': 0.1
#           , 'reg_alpha': 0.5
          ,'max_depth': 10, 'n_estimators': 200
         }

xgbranker = xgb.XGBRanker(**params)

# Choose only columns that are numeric
xgbranker.fit(X,
           y, np.unique(query_ids, return_counts=True)[1],
           eval_metric='ndcg',
           verbose=False)

xgb_scores = xgbranker.predict(X)
xgb_scores
# Out:
# array([-1.0286204 , -1.0286204 ,  3.3731265 , -1.556959  , -1.556959  ,
#        -1.556959  ,  5.700319  ,  0.81466836,  0.81466836, -0.08042699,
#         2.8360608 , -0.5571504 , -0.5571504 ,  0.46133658, -0.7235027 ,
#        -0.7235027 , -0.7235027 , -0.7235027 , -1.1874537 , -2.1594584 ,
#         3.7166448 , -2.2400503 , -2.2400503 ,  0.5092184 , -0.9456975 ,
#        -0.9456975 , -0.9456975 , -0.9456975 , -2.7340033 , -2.808598  ,
#        -0.2104939 ,  3.0177634 , -1.5361079 ,  0.7501865 , -1.0286204 ,
#        -1.0286204 ,  3.3731265 , -0.3694283 , -1.556959  , -1.556959  ,
#        -1.556959  ,  5.700319  ,  0.81466836, -0.08042699, -1.2458773 ,
#         3.7166448 , -2.2400503 , -2.2400503 ,  0.5092184 , -0.9456975 ,
#        -0.9456975 , -0.9456975 , -0.9456975 , -2.7340033 , -2.808598  ],
#       dtype=float32)

# %% [markdown]
# Make sure that your xgboost version is the latest (1.3.3) before proceeding further.

# %%
xgb.__version__
# Out:
# '1.3.3'

# %%
output_score = pd.DataFrame(xgb_scores)
output_score.columns=['score']
output_score_sorted = output_score.sort_values('score', ascending = True).reset_index()
num_rows = output_score_sorted.shape[0]
demo_query_dataset['index'] = demo_query_dataset.index
check_acc = demo_query_dataset.merge(output_score_sorted, on = ['index'])
check_acc
# Out:
#     Column1  @search.features.keyphrases.similarityScore  \
# 34                                      1.0       2.546375
# 35                                      1.0       2.546375
# 36                                      1.0       2.461978
# 37                                      1.0       2.432947
# 38                                      1.0       2.414292
# 39                                      1.0       2.414292
# 40                                      1.0       2.414292
# 41                                      1.0       2.385969
# 42                                      1.0       2.285828
# 43                                      1.0       2.155819
# 44                                      1.0       1.423373
# 45                                      1.0       2.152496
# 46                                      1.0       2.001342
# 47                                      1.0       2.001342
# 48                                      1.0       1.968929
# 49                                      1.0       1.854329
# 50                                      1.0       1.854329
# 51                                      1.0       1.854329
# 52                                      1.0       1.854329
# 53                                      1.0       1.705547
# 54                                      0.0       1.075405
#
#                               AzureSearch_DocumentKey  grade      keyphrases  \
# 0   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      7  ['powershell']
# 1   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      6  ['powershell']
# 2   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      9  ['powershell']
# 3   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      5  ['powershell']
# 4   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      4  ['powershell']
# 5   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      2  ['powershell']
# 6   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...     10  ['powershell']
# 7   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      8  ['powershell']
# 8   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      3  ['powershell']
# 9   aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      1  ['powershell']
# 10  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...     10    ['power bi']
# 11  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      5    ['power bi']
# 12  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      1    ['power bi']
# 13  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      8    ['power bi']
# 14  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      9    ['power bi']
# 15  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      7    ['power bi']
# 16  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      4    ['power bi']
# 17  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      3    ['power bi']
# 18  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      6    ['power bi']
# 19  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      2    ['power bi']
# 20  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...     10    ['power bi']
# 21  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      5    ['power bi']
# 22  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      1    ['power bi']
# 23  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      8    ['power bi']
# 24  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      9    ['power bi']
# 25  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      7    ['power bi']
# 26  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      4    ['power bi']
# 27  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      3    ['power bi']
# 28  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      6    ['power bi']
# 29  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      2    ['power bi']
# 30  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      2    ['power bi']
# 31  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      3  ['powershell']
# 32  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      1    ['power bi']
# 33  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      3  ['powershell']
# 34  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      7  ['powershell']
# 35  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      6  ['powershell']
# 36  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      9  ['powershell']
# 37  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      2    ['power bi']
# 38  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      5  ['powershell']
# 39  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      4  ['powershell']
# 40  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      2  ['powershell']
# 41  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...     10  ['powershell']
# 42  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      8  ['powershell']
# 43  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      1  ['powershell']
# 44  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      1    ['power bi']
# 45  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...     10    ['power bi']
# 46  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      5    ['power bi']
# 47  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      1    ['power bi']
# 48  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      8    ['power bi']
# 49  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      9    ['power bi']
# 50  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      7    ['power bi']
# 51  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      4    ['power bi']
# 52  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      3    ['power bi']
# 53  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      6    ['power bi']
# 54  aHR0cHM6Ly9jc2lkZW1haWxkYXRhLmJsb2IuY29yZS53aW...      2    ['power bi']
#
#                query  sessionid  \
# 0         powershell          1
# 1         powershell          1
# 2         powershell          1
# 3         powershell          1
# 4         powershell          1
# 5         powershell          1
# 6         powershell          1
# 7         powershell          1
# 8         powershell          1
# 9         powershell          1
# 10          power bi          2
# 11          power bi          2
# 12          power bi          2
# 13          power bi          2
# 14          power bi          2
# 15          power bi          2
# 16          power bi          2
# 17          power bi          2
# 18          power bi          2
# 19          power bi          2
# 20             power          3
# 21             power          3
# 22             power          3
# 23             power          3
# 24             power          3
# 25             power          3
# 26             power          3
# 27             power          3
# 28             power          3
# 29             power          3
# 30             azure          4
# 31             azure          4
# 32             azure          4
# 33  azure powershell          5
# 34  azure powershell          5
# 35  azure powershell          5
# 36  azure powershell          5
# 37  azure powershell          5
# 38  azure powershell          5
# 39  azure powershell          5
# 40  azure powershell          5
# 41  azure powershell          5
# 42  azure powershell          5
# 43  azure powershell          5
# 44  azure powershell          5
# 45             power          6
# 46             power          6
# 47             power          6
# 48             power          6
# 49             power          6
# 50             power          6
# 51             power          6
# 52             power          6
# 53             power          6
# 54             power          6
#
#                                                   url  index     score
# 0   https://docs.microsoft.com/en-us/powershell/sc...      0 -1.028620
# 1   https://docs.microsoft.com/en-us/powershell/sc...      1 -1.028620
# 2        https://docs.microsoft.com/en-us/powershell/      2  3.373127
# 3   https://docs.microsoft.com/en-us/powershell/sc...      3 -1.556959
# 4   https://docs.microsoft.com/en-us/powershell/sc...      4 -1.556959
# 5   https://docs.microsoft.com/en-us/powershell/sc...      5 -1.556959
# 6   https://docs.microsoft.com/en-us/powershell/sc...      6  5.700319
# 7   https://docs.microsoft.com/en-us/windows-serve...      7  0.814668
# 8   https://docs.microsoft.com/en-us/powershell/az...      8  0.814668
# 9   https://docs.microsoft.com/en-us/virtualizatio...      9 -0.080427
# 10  https://docs.microsoft.com/en-us/power-bi/fund...     10  2.836061
# 11  https://docs.microsoft.com/en-us/power-bi/serv...     11 -0.557150
# 12  https://docs.microsoft.com/en-us/power-bi/serv...     12 -0.557150
# 13         https://docs.microsoft.com/en-us/power-bi/     13  0.461337
# 14  https://docs.microsoft.com/en-us/power-bi/guid...     14 -0.723503
# 15  https://docs.microsoft.com/en-us/power-bi/serv...     15 -0.723503
# 16  https://docs.microsoft.com/en-us/power-bi/desk...     16 -0.723503
# 17  https://docs.microsoft.com/en-us/power-bi/desk...     17 -0.723503
# 18  https://docs.microsoft.com/en-us/learn/modules...     18 -1.187454
# 19  https://docs.microsoft.com/en-us/azure/azure-m...     19 -2.159458
# 20  https://docs.microsoft.com/en-us/power-bi/fund...     20  3.716645
# 21  https://docs.microsoft.com/en-us/power-bi/serv...     21 -2.240050
# 22  https://docs.microsoft.com/en-us/power-bi/serv...     22 -2.240050
# 23         https://docs.microsoft.com/en-us/power-bi/     23  0.509218
# 24  https://docs.microsoft.com/en-us/power-bi/guid...     24 -0.945697
# 25  https://docs.microsoft.com/en-us/power-bi/serv...     25 -0.945697
# 26  https://docs.microsoft.com/en-us/power-bi/desk...     26 -0.945697
# 27  https://docs.microsoft.com/en-us/power-bi/desk...     27 -0.945697
# 28  https://docs.microsoft.com/en-us/learn/modules...     28 -2.734003
# 29  https://docs.microsoft.com/en-us/azure/azure-m...     29 -2.808598
# 30  https://docs.microsoft.com/en-us/azure/azure-m...     30 -0.210494
# 31  https://docs.microsoft.com/en-us/powershell/az...     31  3.017763
# 32  https://docs.microsoft.com/en-us/power-bi/serv...     32 -1.536108
# 33  https://docs.microsoft.com/en-us/powershell/az...     33  0.750187
# 34  https://docs.microsoft.com/en-us/powershell/sc...     34 -1.028620
# 35  https://docs.microsoft.com/en-us/powershell/sc...     35 -1.028620
# 36       https://docs.microsoft.com/en-us/powershell/     36  3.373127
# 37  https://docs.microsoft.com/en-us/azure/azure-m...     37 -0.369428
# 38  https://docs.microsoft.com/en-us/powershell/sc...     38 -1.556959
# 39  https://docs.microsoft.com/en-us/powershell/sc...     39 -1.556959
# 40  https://docs.microsoft.com/en-us/powershell/sc...     40 -1.556959
# 41  https://docs.microsoft.com/en-us/powershell/sc...     41  5.700319
# 42  https://docs.microsoft.com/en-us/windows-serve...     42  0.814668
# 43  https://docs.microsoft.com/en-us/virtualizatio...     43 -0.080427
# 44  https://docs.microsoft.com/en-us/power-bi/serv...     44 -1.245877
# 45  https://docs.microsoft.com/en-us/power-bi/fund...     45  3.716645
# 46  https://docs.microsoft.com/en-us/power-bi/serv...     46 -2.240050
# 47  https://docs.microsoft.com/en-us/power-bi/serv...     47 -2.240050
# 48         https://docs.microsoft.com/en-us/power-bi/     48  0.509218
# 49  https://docs.microsoft.com/en-us/power-bi/guid...     49 -0.945697
# 50  https://docs.microsoft.com/en-us/power-bi/serv...     50 -0.945697
# 51  https://docs.microsoft.com/en-us/power-bi/desk...     51 -0.945697
# 52  https://docs.microsoft.com/en-us/power-bi/desk...     52 -0.945697
# 53  https://docs.microsoft.com/en-us/learn/modules...     53 -2.734003
# 54  https://docs.microsoft.com/en-us/azure/azure-m...     54 -2.808598

# %% [markdown]
# Create ndcg score to check if the xgboost model has a higher ratings than the azure search output

# %%
def dcg_score(y_true, y_score, k=50, gains="exponential"):
    """Discounted cumulative gain (DCG) at rank k
    Parameters
    ----------
    y_true : array-like, shape = [n_samples]
        Ground truth (true relevance labels).
    y_score : array-like, shape = [n_samples]
        Predicted scores.
    k : int
        Rank.
    gains : str
        Whether gains should be "exponential" (default) or "linear".
    Returns
    -------
    DCG @k : float
    """
    order = np.argsort(y_score)[::-1]
    y_true = np.take(y_true, order[:k])
    if gains == "exponential":
        gains = 2 ** y_true - 1
    elif gains == "linear":
        gains = y_true
    else:
        raise ValueError("Invalid gains option.")

    # highest rank is 1 so +2 instead of +1
    discounts = np.log2(np.arange(len(y_true)) + 2)
    return np.sum(gains / discounts)

def ndcg_score(y_true, y_score, k=50, gains="exponential"):
    """Normalized discounted cumulative gain (NDCG) at rank k
    Parameters
    ----------
    y_true : array-like, shape = [n_samples]
        Ground truth (true relevance labels).
    y_score : array-like, shape = [n_samples]
        Predicted scores.
    k : int
        Rank.
    gains : str
        Whether gains should be "exponential" (default) or "linear".
    Returns
    -------
    NDCG @k : float
    """
    best = dcg_score(y_true, y_true, k, gains)
    actual = dcg_score(y_true, y_score, k, gains)
    return actual / best

# %%
azs_search = check_acc.sort_values(['sessionid', '@search.score'], ascending = False)\
[['url', 'grade', 'sessionid']].reset_index(drop = True)
xgboost = check_acc.sort_values(['sessionid','score'], ascending = False)\
[['url','grade', 'sessionid']].reset_index(drop = True)

xgboost_ndcg = ndcg_score(check_acc.sort_values(['sessionid', 'grade'], ascending = False).grade
           , xgboost.grade)

azs_search_ndcg = ndcg_score(check_acc.sort_values(['sessionid', 'grade'], ascending = False).grade
           , azs_search.grade)

print(azs_search_ndcg, xgboost_ndcg)
# Out:
# 0.7955279239907903 0.9740567535075123

# %% [markdown]
# Consolidating the output from our xgboost and check if there is any difference between our url from azure search service and our xgboost model that we run earlier.

# %%
compare_df = pd.concat([azs_search[['url', 'grade']], xgboost[['url', 'grade']]], axis = 1)
compare_df.columns = ['azs_search_url','azs_search_grade','xgboost_url','xgboost_grade']
compare_df.head()
# Out:
#                                       azs_search_url  azs_search_grade  \
# 0  https://docs.microsoft.com/en-us/power-bi/fund...                10
# 1  https://docs.microsoft.com/en-us/power-bi/serv...                 5
# 2  https://docs.microsoft.com/en-us/power-bi/serv...                 1
# 3         https://docs.microsoft.com/en-us/power-bi/                 8
# 4  https://docs.microsoft.com/en-us/power-bi/guid...                 9
#
#                                          xgboost_url  xgboost_grade
# 0  https://docs.microsoft.com/en-us/power-bi/fund...             10
# 1         https://docs.microsoft.com/en-us/power-bi/              8
# 2  https://docs.microsoft.com/en-us/power-bi/guid...              9
# 3  https://docs.microsoft.com/en-us/power-bi/serv...              7
# 4  https://docs.microsoft.com/en-us/power-bi/desk...              4

# %% [markdown]
# ## Model Training
#
# For this task, submit a job to train model in your local machine. To submit a job you:
#
# * Create training scripts
# * Create training environment
# * Submit a run
#
# The training results will be stored in your Azure ML workspace.

# %% [markdown]
# ## Step 1. Create training scripts
#
# Create training scripts in the directory you just created. Notice how the script saves the model:
#
# + The training script saves your model into a directory named outputs. <br>
# `joblib.dump(value=clf, filename='outputs/predict-link-demoxgboostmodel.pkl')`<br>
# Anything written in this directory is automatically uploaded into your workspace. You'll access your model from this directory later in the tutorial. <br>
#  <br>
# + The first script (train_link_xgboost.py) reads in the credentials to generate our training dataset. The second script follows the same model building code that we use to build and train our model. <br>
#  <br>
# + run.log(xxx, yyy) will create a print statement when we submit a run. XXX will be the name and YYY will be the value. It is similar to a log file.
#
# [Run class](https://docs.microsoft.com/en-us/python/api/azureml-core/azureml.core.run(class)?view=azure-ml-py)
#
# [Joblib](https://joblib.readthedocs.io/en/latest/)

# %%
# %%writefile train_link_xgboost.py

# import argparse
import os
from azureml.core import Run
from predict_link_xgboost import generate_model
from joblib import dump
from azure_search_client import azure_search_client as azs_client 
import random
import numpy as np
from random import sample
import pandas as pd

# get hold of the current run
run = Run.get_context()

# Connecting to the api service
azs_service = azs_client.from_json('api_config.json')
run.log('Connecting to api service', azs_service)

# Generate model
xgb_ranker = generate_model(azs_service, run)

# note file saved in the outputs folder is automatically uploaded into experiment record
os.makedirs('outputs', exist_ok=True)
dump(value=xgb_ranker, filename='outputs/predict-link-xgboostmodel.pkl')
run.log('End of run','Training completed')
# Out:
# Overwriting train_link_xgboost.py

# %%
# %%writefile predict_link_xgboost.py

from azureml.core import Run
from pandas.io.json import json_normalize
import pandas as pd
import json
import concurrent
import datetime
from itertools import chain
import random
import numpy as np
from random import sample
import warnings
warnings.filterwarnings("ignore")
from sklearn.model_selection import GroupShuffleSplit
import xgboost as xgb
from sklearn.model_selection import GroupKFold
from tqdm import tqdm

def get_search_results(service, query):
    search_request_body = {
        "search": query,
        "featuresMode": "enabled",
        "scoringStatistics": "global",
        "count": "true"
    }
    
    return service.search(search_request_body)

def retrieve_from_search(query, sessionid, azs_service):
    
    ## Call the api service to retrieve json format data
    json_search_results = get_search_results(azs_service, query)
    
    ## Flatten the json format data into pandas dataframe
    search_results = json_normalize(json_search_results).fillna(0)
    search_results = search_results.fillna(0).sort_values(['@search.score'], ascending=False)
    search_results['query'] = query.lower()
    search_results['sessionid'] = sessionid
    print('{} rows for query : {}'.format(search_results.shape[0], query))
    
    return search_results
 
def dcg_score(y_true, y_score, k=50, gains="exponential"):
    """Discounted cumulative gain (DCG) at rank k
    Parameters
    ----------
    y_true : array-like, shape = [n_samples]
        Ground truth (true relevance labels).
    y_score : array-like, shape = [n_samples]
        Predicted scores.
    k : int
        Rank.
    gains : str
        Whether gains should be "exponential" (default) or "linear".
    Returns
    -------
    DCG @k : float
    """
    order = np.argsort(y_score)[::-1]
    y_true = np.take(y_true, order[:k])
    if gains == "exponential":
        gains = 2 ** y_true - 1
    elif gains == "linear":
        gains = y_true
    else:
        raise ValueError("Invalid gains option.")

    # highest rank is 1 so +2 instead of +1
    discounts = np.log2(np.arange(len(y_true)) + 2)
    return np.sum(gains / discounts)

def ndcg_score(y_true, y_score, k=50, gains="exponential"):
    """Normalized discounted cumulative gain (NDCG) at rank k
    Parameters
    ----------
    y_true : array-like, shape = [n_samples]
        Ground truth (true relevance labels).
    y_score : array-like, shape = [n_samples]
        Predicted scores.
    k : int
        Rank.
    gains : str
        Whether gains should be "exponential" (default) or "linear".
    Returns
    -------
    NDCG @k : float
    """
    best = dcg_score(y_true, y_true, k, gains)
    actual = dcg_score(y_true, y_score, k, gains)
    return actual / best

def generate_model(azs_service, run):
    
    # Create the necessary queries to create dataset
    query_input = ['powershell', 'power bi', 'power', 'azure', 'azure powershell']

    demo_query_dataset = pd.DataFrame()
    sessionid =1
    for query in query_input:
        demo_query_dataset = pd.concat([demo_query_dataset, retrieve_from_search(query, sessionid, azs_service)])
        sessionid+=1

    demo_query_dataset = demo_query_dataset.fillna(0).reset_index(drop =True)
    demo_query_dataset['grade'] = demo_query_dataset.grade.astype(int)
    
    features = ['@search.features.keyphrases.similarityScore',
       '@search.features.keyphrases.termFrequency',
       '@search.features.keyphrases.uniqueTokenMatches',
       '@search.features.query.similarityScore',
       '@search.features.query.termFrequency',
       '@search.features.query.uniqueTokenMatches',
       '@search.features.url.similarityScore',
       '@search.features.url.termFrequency',
       '@search.features.url.uniqueTokenMatches', '@search.score']
    
    X, y = demo_query_dataset[features], demo_query_dataset.grade
    
    # Query labels for each document in our dataset.
    query_ids = demo_query_dataset['sessionid'].to_numpy()


    params = {'objective': 'rank:ndcg', 'learning_rate': 0.5
          ,'min_child_weight': 0.1
#           , 'reg_alpha': 0.5
          ,'max_depth': 10, 'n_estimators': 200
         }

    xgb_ranker = xgb.XGBRanker(**params)
    run.log('Setting up xgb params', params)

    xgb_ranker.fit(X,
           y, np.unique(query_ids, return_counts=True)[1],
           eval_metric='ndcg',
           verbose=False)

    
    xgb_scores = xgb_ranker.predict(X)

    # Create the output dataset and also the accuracy
    output_score = pd.DataFrame(xgb_scores)
    output_score.columns=['score']
    output_score_sorted = output_score.sort_values('score', ascending = True).reset_index()
        
    demo_query_dataset['index'] = demo_query_dataset.index
    check_acc = demo_query_dataset.merge(output_score_sorted, on = ['index'])
    
    azs_search = check_acc.sort_values(['sessionid', '@search.score'], ascending = False)\
    [['url', 'grade', 'sessionid']].reset_index(drop = True)
    xgboost = check_acc.sort_values(['sessionid','score'], ascending = False)\
    [['url','grade', 'sessionid']].reset_index(drop = True)

    xgboost_ndcg = ndcg_score(check_acc.sort_values(['sessionid', 'grade'], ascending = False).grade
                              , xgboost.grade)

    azs_search_ndcg = ndcg_score(check_acc.sort_values(['sessionid', 'grade'], ascending = False).grade
                                 , azs_search.grade)

    run.log('XGboost NDCG is', xgboost_ndcg)
    run.log('Azure Search NDCG is', azs_search_ndcg)
    
    return xgb_ranker
# Out:
# Overwriting predict_link_xgboost.py

# %% [markdown]
# ## Step 3. Create training environment in local machine
#
# The steps here is to create a local training environment, such as to leverage on the Anaconda installed on local machine. However, you can also run this "locally" in the Microsoft Azure Notebooks.
#
# Details are provided at https://docs.microsoft.com/en-us/azure/machine-learning/how-to-configure-environment#local
#
# [What are Azure Machine Learning environments?](https://docs.microsoft.com/en-us/azure/machine-learning/concept-environments)

# %% [markdown]
# ### Define a user-managed environment
# By default, Azure Machine Learning service will build a Conda environment with dependencies you specified, and will execute the run in that environment instead of using any Python libraries that you installed on the base image.
# A later example in this example will demonstrate the use of Environment when training the model on Azure.
#
# In some situations, your custom base image may already contain a Python environment with packages that you want to use.
#
# When using a user-managed environment for local training, you are responsible for ensuring that all the necessary packages are available in the Python environment you choose to run the script in.
#
# + Create and attach: There's no need to create or attach a compute target to use your local computer as the training environment.
# + Configure: When you use your local computer as a compute target, the training code is run in your development environment. If that environment already has the Python packages you need, use the user-managed environment.
#
# To use your own installed packages, set the parameter Environment.python.user_managed_dependencies = True. Ensure that the base image contains a Python interpreter, and has the packages your training script needs.

# %%
from azureml.core import Environment

# Create a 'user-managed environment' environment.
user_managed_env = Environment("user-managed-env-demoxgboost")

user_managed_env.python.user_managed_dependencies = True

# You can choose a specific Python environment by pointing to a Python path 
#user_managed_env.python.interpreter_path = '/home/johndoe/miniconda3/envs/myenv/bin/python'

# %% [markdown]
# ### Create ScriptRunConfig
#
# Whatever the way you manage your environment, you need to use the ScriptRunConfig class. ScriptRunConfig identifies the training script to run in the experiment and the environment in which to run it.
#
# ScriptRunConfig includes
# + source_directory: The source directory that contains your training script
# + script: Identify the training script
# + run_config: The run configuration, which in turn defines where the training will occur
#
# Note: ScriptRunConfig doesn't allow you to pass dataset to the training script.

# %%
directory = os.getcwd()

# %%
from azureml.core import ScriptRunConfig

src = ScriptRunConfig(source_directory= directory, script='train_link_xgboost.py')
src.run_config.environment = user_managed_env

# %% [markdown]
# ## 4. Submit a run
#
# After you create a run configuration, you use it to run your experiment. An experiment is a logical container in an Azure ML Workspace. It contains a series of trials called Runs. As such, it hosts run records such as run metrics, logs, and other output artifacts from your experiments.
#
# The code pattern to submit a training run is the same for all types of compute targets:
# + Create an experiment to run.
# + Submit the run.
# + Wait for the run to complete.

# %% [markdown]
# ### Submit the run

# %%
run = exp.submit(src)
run
# Out:
# Run(Experiment: predict-link-xgboost,
# Id: predict-link-xgboost_1619400023_152aedef,
# Type: azureml.scriptrun,
# Status: Starting)

# %% [markdown]
# ### Wait for the run to complete
#
# After you submit the run, you can immediately execute this code to watch the progress of the run with a Jupyter widget. Like the run submission, the widget is asynchronous and provides live updates every 10 to 15 seconds until the job finishes:
#
# If the run has error, check out azureml-logs/70_control.log.txt. It will have the error stated in this log file

# %%
from azureml.widgets import RunDetails
RunDetails(run).show()
# Out:
# _UserRunWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', '…

# %% [markdown]
# ### Get log results upon completion
#
# Model training and monitoring happen in the background. Wait until the model has finished training before you run more code. Use wait_for_completion to show when the model training is finished:

# %%
# run.wait_for_completion(show_output=False)  # specify True for a verbose log

# %% [markdown]
# Note: All these calculations were run on your local machine, in the conda environment you defined above. You can find the results in:
#
#     + ~/.azureml/envs/azureml_xxxx for the conda environment you just created
#     + ~/AppData/Local/Temp/azureml_runs/train-on-local_xxxx for the machine learning models you trained (this path may differ depending on the platform you use). This folder also contains
#         - Logs (under azureml_logs/)
#         - Output pickled files (under outputs/)
#         - The configuration files (credentials, local and docker image setups)
#         - The train.py and mylib.py scripts
#         - The current notebook
#
# Take a few minutes to examine the output of the cell above. It shows the content of some of the log files, and extra information on the conda environment used.

# %% [markdown]
# ### Display run results
#
# Display the information captured by run.log(). Results will appear only after the run completed.

# %%
print(run.get_metrics())
# Out:
# {'Connecting to api service': '<azure_search_client.azure_search_client object at 0x7f9706000d68>', 'Setting up xgb params': "{'objective': 'rank:ndcg', 'learning_rate': 0.5, 'min_child_weight': 0.1, 'max_depth': 10, 'n_estimators': 200}", 'XGboost NDCG is': 0.9783009542123144, 'Azure Search NDCG is': 0.7557246194876953, 'End of run': 'Training completed'}

# %%
run.get_metrics('Setting up xgb params').get('Setting up xgb params')
# Out:
# "{'objective': 'rank:ndcg', 'learning_rate': 0.5, 'min_child_weight': 0.1, 'max_depth': 10, 'n_estimators': 200}"

# %% [markdown]
# ## Register Model
#
# The last step in the training script wrote the file outputs/predict-emailservice-xgbmodel.pkl in a directory named outputs in the VM of the cluster where the job is run. "outputs" is a special directory in that all content in this directory is automatically uploaded to your workspace. This content appears in the run record in the experiment under your workspace. So the model file is now also available in your workspace.
#
# You can see files associated with that run:

# %%
print(run.get_file_names())
# Out:
# ['azureml-logs/60_control_log.txt', 'azureml-logs/70_driver_log.txt', 'logs/azureml/3923_azureml.log', 'outputs/predict-link-xgboostmodel.pkl']

# %% [markdown]
# Register the model in the workspace, so that you or other collaborators can later query, examine, and deploy this model. You can store the metrics you captured and store them into "tags" in the Model object.

# %%
# Adding metrics to tags so that these information can be used for model comparison purpose.
# metrics = run.get_metrics().keys()
metrics = ['Setting up xgb params', 'XGboost NDCG is', 'Azure Search NDCG is']

tags = {}
for key in metrics:
    tags[key] = run.get_metrics(key).get(key)

# register model, note the metric values are stored in "tags".
model = run.register_model(model_name='predict-link-xgboostmodel',
                           model_path='outputs/predict-link-xgboostmodel.pkl',
                           tags=tags
                          )
print(model.name, model.id, model.version, model.tags, sep='\t')
# Out:
# predict-link-xgboostmodel	predict-link-xgboostmodel:5	5	{'Setting up xgb params': "{'objective': 'rank:ndcg', 'learning_rate': 0.5, 'min_child_weight': 0.1, 'max_depth': 10, 'n_estimators': 200}", 'XGboost NDCG is': '0.9783009542123144', 'Azure Search NDCG is': '0.7557246194876953'}

# %% [markdown]
# Once you have registered the model, you can proceed to Tutorial#2 to deploy the model.
